# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm

# %%
dftrain=pd.read_csv('Whatever you call your training File.csv')

# %%
dftest=pd.read_csv('Whatever you call your testing File.csv')

# %%
model = sm.logit(formula='dependent variable ~ independent variable1+independent variable2+.....................\
                 indendent variablen', data=dftrain).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.283181
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:                  other   No. Observations:                 4824
# Model:                          Logit   Df Residuals:                     4820
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 12 Oct 2023   Pseudo R-squ.:                  0.2972
# Time:                        15:49:14   Log-Likelihood:                -1366.1
# converged:                       True   LL-Null:                       -1943.8
# Covariance Type:            nonrobust   LLR p-value:                3.402e-250
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
Xtest = dftest[['final independent var1', 'final independent var2', ..............'final independent varn']]
ytest = dftest['dependent variable']
  
dest1_yhat = model.predict(Xtest)

# %%
dftest['dest1_yhat'] = dest1_yhat

# %%
print(dest1_yhat)
# Out:
# 0       0.681629
# 1       0.057242
# 2       1.000000
# 3       0.890318
# 4       0.337435
#           ...
# 4818    0.413468
# 4819    0.401542
# 4820    0.170057
# 4821    0.426679
# 4822    0.111477
# Length: 4823, dtype: float64

# %%
dftest = dftest.sort_values(by = 'dest1_yhat', ascending = False)

# %%
dftest['dest1_Quintile'] = pd.qcut(dftest['dest1_yhat'], 5, labels=[i for i in range (5, 0, -1)])

# %%
print(dftest['dest1_Quintile'])
# Out:
# 665     1
# 2       1
# 1399    1
# 12      1
# 4769    1
#        ..
# 4200    5
# 4084    5
# 4082    5
# 4108    5
# 4087    5
# Name: Other_Quintile, Length: 4823, dtype: category
# Categories (5, int64): [5 < 4 < 3 < 2 < 1]

# %%
dftest['dest1_Quintile'] = dftest['dest1_Quintile'].astype('int')

# %%
print(dest1_travelers)

# %%
dftest.to_csv('C:/file path/testfile.csv')
