# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm

# %%
dftrain=pd.read_csv('AAATrain.csv')

# %%
dftest=pd.read_csv('AAATest.csv')

# %%
model = sm.logit(formula='Florida ~ travel_total_bookings + travel_num_cancelled_bookings \
        + travel_daysbetween_booking_depart + travel_revenue_index + travel_tripvalue_index + individual_age + \
        individual_tenure + individual_maritalstatus + individual_education + individual_race + individual_children_7_9 \
        + days_between + Quartile_1 + Quartile_3', data=dftrain).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.499258
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Florida   No. Observations:                45800
# Model:                          Logit   Df Residuals:                    45766
# Method:                           MLE   Df Model:                           33
# Date:                Tue, 16 Jul 2024   Pseudo R-squ.:                 0.02094
# Time:                        14:25:31   Log-Likelihood:                -22866.
# converged:                       True   LL-Null:                       -23355.
# Covariance Type:            nonrobust   LLR p-value:                3.733e-184
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.4036      0.315     -4.456      0.000      -2.021      -0.786
# individual_tenure[T.11 - 15 Years]               0.3429      0.067      5.104      0.000       0.211       0.475
# individual_tenure[T.16+ Years]                   0.1902      0.063      3.036      0.002       0.067       0.313
# individual_tenure[T.2 Years]                     0.1254      0.066      1.894      0.058      -0.004       0.255
# individual_tenure[T.3 Years]                     0.1389      0.082      1.689      0.091      -0.022       0.300
# individual_tenure[T.4 - 6 Years]                 0.2178      0.068      3.185      0.001       0.084       0.352
# individual_tenure[T.7 - 10 Years]                0.2430      0.067      3.633      0.000       0.112       0.374
# individual_tenure[T.Unknown]                     0.1393      0.072      1.943      0.052      -0.001       0.280
# individual_maritalstatus[T.Single]              -0.1807      0.039     -4.659      0.000      -0.257      -0.105
# individual_maritalstatus[T.Unknown]             -0.1448      0.050     -2.881      0.004      -0.243      -0.046
# individual_education[T.Graduate School]         -0.0333      0.046     -0.720      0.472      -0.124       0.057
# individual_education[T.HS Diploma]               0.1090      0.044      2.472      0.013       0.023       0.195
# individual_education[T.Less than HS Diploma]    -0.0709      0.080     -0.885      0.376      -0.228       0.086
# individual_education[T.Some College]             0.0932      0.042      2.243      0.025       0.012       0.175
# individual_education[T.Unknown]                  0.0686      0.054      1.281      0.200      -0.036       0.174
# individual_race[T.Asian]                        -0.5633      0.323     -1.744      0.081      -1.196       0.070
# individual_race[T.Black]                        -0.7577      0.331     -2.292      0.022      -1.406      -0.110
# individual_race[T.Hispanic]                     -0.0305      0.311     -0.098      0.922      -0.640       0.579
# individual_race[T.Middle Eastern]               -0.1486      0.314     -0.474      0.635      -0.763       0.466
# individual_race[T.Unknown]                      -0.1138      0.308     -0.369      0.712      -0.717       0.490
# individual_race[T.White]                        -0.1287      0.307     -0.420      0.675      -0.729       0.472
# individual_children_7_9[T.Unknown]              -0.1058      0.052     -2.031      0.042      -0.208      -0.004
# individual_children_7_9[T.Yes]                   0.1114      0.043      2.615      0.009       0.028       0.195
# days_between[T.100-250 Days]                     0.0969      0.076      1.269      0.205      -0.053       0.247
# days_between[T.31-100 Days]                      0.2401      0.034      7.001      0.000       0.173       0.307
# days_between[T.>250 Days]                       -0.3840      0.168     -2.280      0.023      -0.714      -0.054
# travel_total_bookings                            0.1279      0.019      6.852      0.000       0.091       0.165
# travel_num_cancelled_bookings                   -0.0979      0.020     -4.964      0.000      -0.137      -0.059
# travel_daysbetween_booking_depart               -0.0009      0.000     -1.881      0.060      -0.002    3.73e-05
# travel_revenue_index                            -0.2086      0.012    -16.770      0.000      -0.233      -0.184
# travel_tripvalue_index                           0.0538      0.010      5.611      0.000       0.035       0.073
# individual_age                                  -0.0019      0.001     -2.478      0.013      -0.003      -0.000
# Quartile_1                                       0.0675      0.033      2.057      0.040       0.003       0.132
# Quartile_3                                       2.6760      0.843      3.176      0.001       1.025       4.327
# ================================================================================================================

# %%
Xtest = dftest[['travel_total_bookings', 'travel_num_cancelled_bookings', 'travel_daysbetween_booking_depart', \
                'travel_revenue_index', 'travel_tripvalue_index', 'individual_age', 'individual_tenure', \
                'individual_maritalstatus', 'individual_education', 'individual_race', 'individual_children_7_9', \
                'days_between', 'Quartile_1', 'Quartile_3']]
ytest = dftest['Florida']

# %%
dest1_yhat = model.predict(Xtest)

# %%
dftest['dest1_yhat'] = dest1_yhat

# %%
print(dest1_yhat)
# Out:
# 0        0.152947
# 1        0.266984
# 2        0.272783
# 3        0.198313
# 4        0.177383
#            ...
# 45795    0.223453
# 45796    0.186930
# 45797    0.169325
# 45798    0.238958
# 45799    0.208137
# Length: 45800, dtype: float64

# %%
dftest = dftest.sort_values(by = 'dest1_yhat', ascending = False)

# %%
dftest['dest1_Quintile'] = pd.qcut(dftest['dest1_yhat'], 5, labels=[i for i in range (5, 0, -1)])

# %%
print(dftest['dest1_Quintile'])
# Out:
# 33682    1
# 26530    1
# 10137    1
# 21550    1
# 3693     1
#         ..
# 8479     5
# 28525    5
# 28024    5
# 18654    5
# 5570     5
# Name: dest1_Quintile, Length: 45800, dtype: category
# Categories (5, int64): [5 < 4 < 3 < 2 < 1]

# %%
dftest['dest1_Quintile'] = dftest['dest1_Quintile'].astype('int')

# %%
dest1_travelers = pd.crosstab(dftest['dest1_Quintile'], dftest['Florida'], normalize='index')

# %%
print(dest1_travelers)
# Out:
# Florida                0         1
# dest1_Quintile
# 1               0.715502  0.284498
# 2               0.765830  0.234170
# 3               0.775873  0.224127
# 4               0.825437  0.174563
# 5               0.884279  0.115721

# %%
dftest.to_csv('testfile.csv')
